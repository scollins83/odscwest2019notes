# %% [markdown]
# <a href="https://colab.research.google.com/github/scollins83/odscwest2019notes/blob/master/ODSC_2019_Optuna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **To edit or run this Jupyter Notebook, go to `File` and `Make a Copy` to your own Google Drive and open with Colaboratory.**

# %% [markdown]
# ![Optuna](https://raw.githubusercontent.com/pfnet/optuna/master/docs/image/optuna-logo.png)

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.6/dist-packages (0.17.1)
# Requirement already satisfied: cliff in /usr/local/lib/python3.6/dist-packages (from optuna) (2.16.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.10)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from optuna) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.1)
# Requirement already satisfied: alembic in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.0)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from optuna) (3.6.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.17.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.6/dist-packages (from optuna) (4.0.2)
# Requirement already satisfied: PrettyTable<0.8,>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (0.7.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (5.4.3)
# Requirement already satisfied: pyparsing>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (2.4.2)
# Requirement already satisfied: stevedore>=1.20.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (1.31.0)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.13)
# Requirement already satisfied: cmd2!=0.8.3,<0.9.0,>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (0.8.9)
# Requirement already satisfied: python-editor>=0.3 in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (1.0.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (1.1.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (2.6.1)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,<0.9.0,>=0.8.0->cliff->optuna) (1.7.0)
# Requirement already satisfied: wcwidth; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,<0.9.0,>=0.8.0->cliff->optuna) (0.1.7)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna) (1.1.1)

# %%
import optuna

def objective(trial):
    x = trial.suggest_uniform('x', -100, 100)
    return 3 * (x ** 4) - 2*(x ** 3) - 4*(x ** 2) + 2

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2019-11-01 22:16:19,892] Finished trial#0 resulted in value: 4778412.503617205. Current best value is 4778412.503617205 with parameters: {'x': 35.70284835868139}.
# [I 2019-11-01 22:16:19,958] Finished trial#1 resulted in value: 84694.3497387006. Current best value is 84694.3497387006 with parameters: {'x': -12.823843880471514}.
# [I 2019-11-01 22:16:20,021] Finished trial#2 resulted in value: 21807.09038953073. Current best value is 21807.09038953073 with parameters: {'x': -9.105983459939068}.
# [I 2019-11-01 22:16:20,110] Finished trial#3 resulted in value: 6452.935533317645. Current best value is 6452.935533317645 with parameters: {'x': 7.034241121960406}.
# [I 2019-11-01 22:16:20,177] Finished trial#4 resulted in value: 198416186.82029963. Current best value is 6452.935533317645 with parameters: {'x': 7.034241121960406}.
# [I 2019-11-01 22:16:20,244] Finished trial#5 resulted in value: 606624.3421203812. Current best value is 6452.935533317645 with parameters: {'x': 7.034241121960406}.
# [I 2019-11-01 22:16:20,311] Finished trial#6 resulted in value: 1473.250626496854. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,378] Finished trial#7 resulted in value: 1406658.2503317213. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,444] Finished trial#8 resulted in value: 494638.7993603883. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,511] Finished trial#9 resulted in value: 135093470.99849162. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,579] Finished trial#10 resulted in value: 18400169.847471744. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,653] Finished trial#11 resulted in value: 224756328.3566322. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,726] Finished trial#12 resulted in value: 51947118.23687101. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,806] Finished trial#13 resulted in value: 12427819.001911623. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,885] Finished trial#14 resulted in value: 31275079.4636015. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:20,961] Finished trial#15 resulted in value: 14240.497541934454. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:21,029] Finished trial#16 resulted in value: 4064826.2004682757. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:21,106] Finished trial#17 resulted in value: 28122084.449388858. Current best value is 1473.250626496854 with parameters: {'x': 4.958424206375284}.
# [I 2019-11-01 22:16:21,188] Finished trial#18 resulted in value: 1.871464948434907. Current best value is 1.871464948434907 with parameters: {'x': 1.5275201580142062}.
# [I 2019-11-01 22:16:21,256] Finished trial#19 resulted in value: 58408364.891874395. Current best value is 1.871464948434907 with parameters: {'x': 1.5275201580142062}.
# [I 2019-11-01 22:16:21,322] Finished trial#20 resulted in value: 155749501.74502984. Current best value is 1.871464948434907 with parameters: {'x': 1.5275201580142062}.
# [I 2019-11-01 22:16:21,401] Finished trial#21 resulted in value: 287.44447022532694. Current best value is 1.871464948434907 with parameters: {'x': 1.5275201580142062}.
# [I 2019-11-01 22:16:21
Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:25,907] Finished trial#74 resulted in value: 0.6972546073406685. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:25,992] Finished trial#75 resulted in value: 125630.94658658758. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,077] Finished trial#76 resulted in value: 3210.9384076365914. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,159] Finished trial#77 resulted in value: 903803.9066781093. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,246] Finished trial#78 resulted in value: 1.1392745783475475. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,322] Finished trial#79 resulted in value: 2797500.294703887. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,417] Finished trial#80 resulted in value: 969606.0722700144. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,507] Finished trial#81 resulted in value: 0.7830185701749883. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,586] Finished trial#82 resulted in value: 19551.592956780398. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,668] Finished trial#83 resulted in value: 148375.09049514242. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,754] Finished trial#84 resulted in value: 1827.717248807274. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,845] Finished trial#85 resulted in value: 14849.272348782815. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:26,931] Finished trial#86 resulted in value: 305.9943933684328. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:27,015] Finished trial#87 resulted in value: 148119.33305417545. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:27,101] Finished trial#88 resulted in value: 348758.82274685183. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:27,184] Finished trial#89 resulted in value: 259.5595228211811. Current best value is -0.4427641673060059 with parameters: {'x': 0.8217101113902907}.
# [I 2019-11-01 22:16:27,272] Finished trial#90 resulted in value: -1.0752994315568314. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:27,353] Finished trial#91 resulted in value: 0.7391439988324873. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:27,444] Finished trial#92 resulted in value: 36120.819146707705. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:27,538] Finished trial#93 resulted in value: 887.6139747173207. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:27,619] Finished trial#94 resulted in value: 6098.837240266822. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:27,700] Finished trial#95 resulted in value: 51977.027907008276. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:27,782] Finished trial#96 resulted in value: 51484.77362796916. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:27,868] Finished trial#97 resulted in value: 16.007452513679965. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:27,955] Finished trial#98 resulted in value: 2302321.9515259233. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.
# [I 2019-11-01 22:16:28,040] Finished trial#99 resulted in value: 256498.24905371375. Current best value is -1.0752994315568314 with parameters: {'x': 1.157754616566383}.

# %%
print('Minimum objective value: ' + str(study.best_value))
print('Best parameter: ' + str(study.best_params))
# Out:
# Minimum objective value: -1.0752994315568314
# Best parameter: {'x': 1.157754616566383}

# %%
correct_answer = 1.039
print('Correct answer: ' + str(correct_answer))
print('Error: ' + str(round((study.best_params['x']-1.039)/200 * 100, 4)) + '%')
# Out:
# Correct answer: 1.039
# Error: 0.0594%

# %%
import optuna
import sklearn.datasets
import sklearn.linear_model
import sklearn.metrics

def objective(trial):
    # hyperparameter setting
    alpha = trial.suggest_loguniform('alpha', 1e-20, 10)
    
    # data loading and train-test split
    X, y = sklearn.datasets.load_boston(return_X_y=True)
    X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, y, random_state=0)
    
    # model training and evaluation
    model = sklearn.linear_model.Lasso(alpha=alpha)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    error = sklearn.metrics.mean_squared_error(y_val, y_pred)

    # output: evaluation score
    return error

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3687.821206779532, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:28,508] Finished trial#0 resulted in value: 29.782245092302404. Current best value is 29.782245092302404 with parameters: {'alpha': 8.18468470108775e-17}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3721.865008867251, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:28,620] Finished trial#1 resulted in value: 29.782245092302475. Current best value is 29.782245092302404 with parameters: {'alpha': 8.18468470108775e-17}.
# [I 2019-11-01 22:16:28,725] Finished trial#2 resulted in value: 31.395688552006956. Current best value is 29.782245092302404 with parameters: {'alpha': 8.18468470108775e-17}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3721.236367242447, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:28,835] Finished trial#3 resulted in value: 29.782245092302475. Current best value is 29.782245092302404 with parameters: {'alpha': 8.18468470108775e-17}.
# [I 2019-11-01 22:16:28,930] Finished trial#4 resulted in value: 31.534240177894862. Current best value is 29.782245092302404 with parameters: {'alpha': 8.18468470108775e-17}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3721.8692585057865, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16
tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:33,416] Finished trial#46 resulted in value: 29.782245092302386. Current best value is 29.782245092302386 with parameters: {'alpha': 2.4617684839377317e-17}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.13341477661288, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:33,528] Finished trial#47 resulted in value: 29.782245092303643. Current best value is 29.782245092302386 with parameters: {'alpha': 2.4617684839377317e-17}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3046.741324016852, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:33,644] Finished trial#48 resulted in value: 29.78224509230274. Current best value is 29.782245092302386 with parameters: {'alpha': 2.4617684839377317e-17}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3720.1509649094164, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:33,769] Finished trial#49 resulted in value: 29.78224509230244. Current best value is 29.782245092302386 with parameters: {'alpha': 2.4617684839377317e-17}.

# %%
print('Minimum mean squared error: ' + str(study.best_value))
print('Best parameter: ' + str(study.best_params))
# Out:
# Minimum mean squared error: 29.782245092302386
# Best parameter: {'alpha': 2.4617684839377317e-17}

# %%
study.trials_dataframe()
# Out:
#    number                state  ...        params system_attrs
#                                 ...         alpha      _number
# 0       0  TrialState.COMPLETE  ...  8.184685e-17            0
# 1       1  TrialState.COMPLETE  ...  3.434737e-20            1
# 2       2  TrialState.COMPLETE  ...  3.722721e-02            2
# 3       3  TrialState.COMPLETE  ...  1.643046e-18            3
# 4       4  TrialState.COMPLETE  ...  3.948305e-02            4
# 5       5  TrialState.COMPLETE  ...  2.347297e-20            5
# 6       6  TrialState.COMPLETE  ...  1.209237e-07            6
# 7       7  TrialState.COMPLETE  ...  2.037754e-05            7
# 8       8  TrialState.COMPLETE  ...  1.680885e-04            8
# 9       9  TrialState.COMPLETE  ...  5.547487e-17            9
# 10     10  TrialState.COMPLETE  ...  1.890504e-13           10
# 11     11  TrialState.COMPLETE  ...  5.419368e-14           11
# 12     12  TrialState.COMPLETE  ...  9.815533e-16           12
# 13     13  TrialState.COMPLETE  ...  2.293017e-14           13
# 14     14  TrialState.COMPLETE  ...  1.794482e-11           14
# 15     15  TrialState.COMPLETE  ...  3.270129e-16           15
# 16     16  TrialState.COMPLETE  ...  1.756700e-10           16
# 17     17  TrialState.COMPLETE  ...  1.581121e-17           17
# 18     18  TrialState.COMPLETE  ...  1.646574e-20           18
# 19     19  TrialState.COMPLETE  ...  1.637877e-12           19
# 20     20  TrialState.COMPLETE  ...  2.083483e-08           20
# 21     21  TrialState.COMPLETE  ...  4.920948e-15           21
# 22     22  TrialState.COMPLETE  ...  1.071688e-15           22
# 23     23  TrialState.COMPLETE  ...  1.453850e-18           23
# 24     24  TrialState.COMPLETE  ...  2.688313e-16           24
# 25     25  TrialState.COMPLETE  ...  6.560263e-19           25
# 26     26  TrialState.COMPLETE  ...  2.178499e-12           26
# 27     27  TrialState.COMPLETE  ...  3.541280e-16           27
# 28     28  TrialState.COMPLETE  ...  5.379337e-09           28
# 29     29  TrialState.COMPLETE  ...  1.547271e-19           29
# 30     30  TrialState.COMPLETE  ...  2.944534e-17           30
# 31     31  TrialState.COMPLETE  ...  1.688921e-17           31
# 32     32  TrialState.COMPLETE  ...  9.317713e-18           32
# 33     33  TrialState.COMPLETE  ...  5.662023e-18           33
# 34     34  TrialState.COMPLETE  ...  1.134924e-19           34
# 35     35  TrialState.COMPLETE  ...  1.249404e-20           35
# 36     36  TrialState.COMPLETE  ...  6.822665e-17           36
# 37     37  TrialState.COMPLETE  ...  4.141956e-18           37
# 38     38  TrialState.COMPLETE  ...  5.823217e-15           38
# 39     39  TrialState.COMPLETE  ...  5.392696e-13           39
# 40     40  TrialState.COMPLETE  ...  1.587436e-19           40
# 41     41  TrialState.COMPLETE  ...  5.387289e-17           41
# 42     42  TrialState.COMPLETE  ...  3.657877e+00           42
# 43     43  TrialState.COMPLETE  ...  2.457284e-15           43
# 44     44  TrialState.COMPLETE  ...  1.840487e-17           44
# 45     45  TrialState.COMPLETE  ...  1.204995e-18           45
# 46     46  TrialState.COMPLETE  ...  2.461768e-17           46
# 47     47  TrialState.COMPLETE  ...  4.690930e-14           47
# 48     48  TrialState.COMPLETE  ...  1.049109e-14           48
# 49     49  TrialState.COMPLETE  ...  9.729504e-18           49
#
# [50 rows x 7 columns]

# %%
import optuna
import sklearn.datasets
import sklearn.linear_model
import sklearn.metrics

def objective(trial):
    # hyperparameter setting
    
    regression_method = trial.suggest_categorical('regression_method', ('Ridge', 'Lasso'))
    regression_alpha = trial.suggest_loguniform(regression_method, 1e-20, 10)
    model = getattr(sklearn.linear_model, regression_method)(alpha=regression_alpha)
    # getattr same as 'sklearn.linear_model.Ridge(alpha=regression_alpha)'
    # or 'sklearn.linear_model.Lasso(alpha=regression_alpha)'
    
    # data loading and train-test split
    X, y = sklearn.datasets.load_boston(return_X_y=True)
    X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, y, random_state=0)

    # model training and evaluation
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    error = sklearn.metrics.mean_squared_error(y_val, y_pred)
  
    # output: evaluation score
    return error

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)
# Out:
# [I 2019-11-01 22:16:34,010] Finished trial#0 resulted in value: 29.782245314878402. Current best value is 29.782245314878402 with parameters: {'regression_method': 'Lasso', 'Lasso': 8.45842115505212e-09}.
# [I 2019-11-01 22:16:34,114] Finished trial#1 resulted in value: 29.782245276691196. Current best value is 29.782245276691196 with parameters: {'regression_method': 'Lasso', 'Lasso': 7.0070985432458415e-09}.
# [I 2019-11-01 22:16:34,206] Finished trial#2 resulted in value: 29.78224517173018. Current best value is 29.78224517173018 with parameters: {'regression_method': 'Lasso', 'Lasso': 3.018442714414239e-09}.
# [I 2019-11-01 22:16:34,299] Finished trial#3 resulted in value: 29.782466724985195. Current best value is 29.78224517173018 with parameters: {'regression_method': 'Lasso', 'Lasso': 3.018442714414239e-09}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3392.533615504505, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:34,426] Finished trial#4 resulted in value: 29.782245092302496. Current best value is 29.782245092302496 with parameters: {'regression_method': 'Lasso', 'Lasso': 1.5276545734397332e-15}.
# [I 2019-11-01 22:16:34,538] Finished trial#5 resulted in value: 29.78224513617712. Current best value is 29.782245092302496 with parameters: {'regression_method': 'Lasso', 'Lasso': 1.5276545734397332e-15}.
# [I 2019-11-01 22:16:34,646] Finished trial#6 resulted in value: 29.782245093826088. Current best value is 29.782245092302496 with parameters: {'regression_method': 'Lasso', 'Lasso': 1.5276545734397332e-15}.
# [I 2019-11-01 22:16:34,758] Finished trial#7 resulted in value: 29.782245092303057. Current best value is 29.782245092302496 with parameters: {'regression_method': 'Lasso', 'Lasso': 1.5276545734397332e-15}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3721.6800701507004, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:34,859] Finished trial#8 resulted in value: 29.782245092302475. Current best value is 29.782245092302475 with parameters: {'regression_method': 'Lasso', 'Lasso': 5.075929212839061e-19}.
# [I 2019-11-01 22:16:34,945] Finished trial#9 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,036] Finished trial#10 resulted in value: 29.78224637450267. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,122] Finished trial#11 resulted in value: 29.782245092421885. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,202] Finished trial#12 resulted in value: 29.782245094513186. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,296] Finished trial#13 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,411] Finished trial#14 resulted in value: 30.205398594966056. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,501] Finished trial#15 resulted in value: 29.78241941212905. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,596] Finished trial#16 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,690] Finished trial#17 resulted in value: 29.782245092306336. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,814] Finished trial#18 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,930] Finished trial#19 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.

# %%
print('Minimum mean squared error: ' + str(study.best_value))
print('Best parameter: ' + str(study.best_params))

study.trials_dataframe()
# Out:
# Minimum mean squared error: 29.78224509230247
# Best parameter: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}
#    number                state  ...            params system_attrs
#                                 ... regression_method      _number
# 0       0  TrialState.COMPLETE  ...             Lasso            0
# 1       1  TrialState.COMPLETE  ...             Lasso            1
# 2       2  TrialState.COMPLETE  ...             Lasso            2
# 3       3  TrialState.COMPLETE  ...             Lasso            3
# 4       4  TrialState.COMPLETE  ...             Lasso            4
# 5       5  TrialState.COMPLETE  ...             Lasso            5
# 6       6  TrialState.COMPLETE  ...             Ridge            6
# 7       7  TrialState.COMPLETE  ...             Lasso            7
# 8       8  TrialState.COMPLETE  ...             Lasso            8
# 9       9  TrialState.COMPLETE  ...             Ridge            9
# 10     10  TrialState.COMPLETE  ...             Ridge           10
# 11     11  TrialState.COMPLETE  ...             Ridge           11
# 12     12  TrialState.COMPLETE  ...             Ridge           12
# 13     13  TrialState.COMPLETE  ...             Ridge           13
# 14     14  TrialState.COMPLETE  ...             Ridge           14
# 15     15  TrialState.COMPLETE  ...             Ridge           15
# 16     16  TrialState.COMPLETE  ...             Ridge           16
# 17     17  TrialState.COMPLETE  ...             Ridge           17
# 18     18  TrialState.COMPLETE  ...             Ridge           18
# 19     19  TrialState.COMPLETE  ...             Ridge           19
#
# [20 rows x 9 columns]

# %%
import optuna
import sklearn.datasets
import sklearn.linear_model
import sklearn.metrics

def objective(trial):
    # hyperparameter setting
    
    regression_method = trial.suggest_categorical('regression_method', ('Ridge', 'Lasso'))
    regression_alpha = trial.suggest_loguniform(regression_method, 1e-20, 10)
    model = getattr(sklearn.linear_model, regression_method)(alpha=regression_alpha)
    # getattr same as 'sklearn.linear_model.Ridge(alpha=regression_alpha)'
    # or 'sklearn.linear_model.Lasso(alpha=regression_alpha)'
    
    # data loading and train-test split
    X, y = sklearn.datasets.load_boston(return_X_y=True)
    X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, y, random_state=0)

    # model training and evaluation
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    error = sklearn.metrics.mean_squared_error(y_val, y_pred)
  
    # output: evaluation score
    return error

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)

print('Minimum mean squared error: ' + str(study.best_value))
print('Best parameter: ' + str(study.best_params))
# Out:
# [I 2019-11-01 22:16:34,010] Finished trial#0 resulted in value: 29.782245314878402. Current best value is 29.782245314878402 with parameters: {'regression_method': 'Lasso', 'Lasso': 8.45842115505212e-09}.
# [I 2019-11-01 22:16:34,114] Finished trial#1 resulted in value: 29.782245276691196. Current best value is 29.782245276691196 with parameters: {'regression_method': 'Lasso', 'Lasso': 7.0070985432458415e-09}.
# [I 2019-11-01 22:16:34,206] Finished trial#2 resulted in value: 29.78224517173018. Current best value is 29.78224517173018 with parameters: {'regression_method': 'Lasso', 'Lasso': 3.018442714414239e-09}.
# [I 2019-11-01 22:16:34,299] Finished trial#3 resulted in value: 29.782466724985195. Current best value is 29.78224517173018 with parameters: {'regression_method': 'Lasso', 'Lasso': 3.018442714414239e-09}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3392.533615504505, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:34,426] Finished trial#4 resulted in value: 29.782245092302496. Current best value is 29.782245092302496 with parameters: {'regression_method': 'Lasso', 'Lasso': 1.5276545734397332e-15}.
# [I 2019-11-01 22:16:34,538] Finished trial#5 resulted in value: 29.78224513617712. Current best value is 29.782245092302496 with parameters: {'regression_method': 'Lasso', 'Lasso': 1.5276545734397332e-15}.
# [I 2019-11-01 22:16:34,646] Finished trial#6 resulted in value: 29.782245093826088. Current best value is 29.782245092302496 with parameters: {'regression_method': 'Lasso', 'Lasso': 1.5276545734397332e-15}.
# [I 2019-11-01 22:16:34,758] Finished trial#7 resulted in value: 29.782245092303057. Current best value is 29.782245092302496 with parameters: {'regression_method': 'Lasso', 'Lasso': 1.5276545734397332e-15}.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3721.6800701507004, tolerance: 3.233182126649076
#
# [I 2019-11-01 22:16:34,859] Finished trial#8 resulted in value: 29.782245092302475. Current best value is 29.782245092302475 with parameters: {'regression_method': 'Lasso', 'Lasso': 5.075929212839061e-19}.
# [I 2019-11-01 22:16:34,945] Finished trial#9 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,036] Finished trial#10 resulted in value: 29.78224637450267. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,122] Finished trial#11 resulted in value: 29.782245092421885. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,202] Finished trial#12 resulted in value: 29.782245094513186. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,296] Finished trial#13 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,411] Finished trial#14 resulted in value: 30.205398594966056. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,501] Finished trial#15 resulted in value: 29.78241941212905. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,596] Finished trial#16 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,690] Finished trial#17 resulted in value: 29.782245092306336. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,814] Finished trial#18 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.
# [I 2019-11-01 22:16:35,930] Finished trial#19 resulted in value: 29.78224509230247. Current best value is 29.78224509230247 with parameters: {'regression_method': 'Ridge', 'Ridge': 2.585381328386492e-19}.

# %%
# Install Chainer, CuPy, and NumPy
import chainer as ch
import numpy as np
import cupy
ch.config.debug = True  # Turn on debugging error messages
import chainer.functions as F
import chainer.links as L
from chainer import iterators
from chainer.datasets.fashion_mnist import get_fashion_mnist
from chainer.training import extensions as E

from optuna.integration import ChainerPruningExtension

# Choose the minibatch size.
batchsize = 128

tot_nodes = 100

# Download the MNIST data if you haven't downloaded it yet
train, test = get_fashion_mnist(withlabel=True, ndim=1)
train, valid = ch.datasets.split_dataset_random(train, 50000, seed=0)

gpu_id = -1  # change to 0 if using GPU

if gpu_id >= 0:
    model_loss.to_gpu(gpu_id)

# %%
def MLP(layers, nodes, activation):
  activation_function = getattr(F, activation)
  layer = ch.Sequential(L.Linear(nodes), activation_function)
  model = layer.repeat(layers)
  model.append(L.Linear(10))
  
  return model

# %%
def objective(trial):
  layers = trial.suggest_int('layers', 1, 100)
  activation = trial.suggest_categorical('activation', ('relu', 'sigmoid', 'tanh'))

  
  print('Layers: ' + str(layers) + ' Nodes: ' + str(int(tot_nodes/layers)) + ' Activation: ' + activation)

  model = MLP(layers, int(tot_nodes/layers), activation)

  model_loss = L.Classifier(model)

  train_iter = iterators.SerialIterator(train, batchsize)
  valid_iter = iterators.SerialIterator(valid, batchsize,
                                       repeat=False, shuffle=False)
  test_iter = iterators.SerialIterator(test, batchsize,
                                       repeat=False, shuffle=False)
  # Choose an optimizer algorithm
  optimizer = ch.optimizers.Adam().setup(model_loss)

  # Create the updater, using the optimizer
  updater = ch.training.StandardUpdater(train_iter, optimizer, device=gpu_id)

  # Set up a trainer
  trainer = ch.training.Trainer(
      updater, (10, 'epoch'), out='result', extensions=[
          E.Evaluator(valid_iter, model_loss, device=gpu_id),
          E.PrintReport(
                ['epoch', 'main/loss', 'validation/main/loss',
                 'main/accuracy', 'validation/main/accuracy', 'elapsed_time'])])

  log_report_extension = ch.training.extensions.LogReport(log_name=None)
  
  trainer.extend(log_report_extension)

  trainer.extend(
    ChainerPruningExtension(trial, 'validation/main/accuracy', (1, 'epoch')))
  
  trainer.run()

  # Set the user attributes such as loss and accuracy for train and validation sets
  log_last = log_report_extension.log[-1]
  for key, value in log_last.items():
      trial.set_user_attr(key, value)

  # Return the validation accuracy
  return log_report_extension.log[-1]['validation/main/accuracy']

# %%
import optuna

# %%
db = 'postgresql://postgres:optuna-berlin@34.89.236.159/demo'
study = optuna.create_study(study_name='odsc',
  storage=db,
  load_if_exists=True,
  direction='maximize',
  pruner=optuna.pruners.MedianPruner())
# Out:
# [I 2019-11-01 22:16:49,264] A new study created with name: zib

# %%
study.optimize(objective, n_trials=3)
# Out:
# Layers: 17 Nodes: 17 Activation: sigmoid
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
# 1           2.30575     2.30371               0.0990649      0.0967168                 31.1615
# 2           2.3035      2.30289               0.0999241      0.101266                  69.236
# 3           2.30323     2.30399               0.100701       0.0989913                 106.713
# 4           2.30363     2.30339               0.0984255      0.0994858                 144.901
# [I 2019-11-01 22:20:39,926] Finished trial#0 resulted in value: 0.09473892405063292. Current best value is 0.0947389240506329 with parameters: {'layers': 17, 'activation': 'sigmoid'}.
# Layers: 25 Nodes: 12 Activation: tanh
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
# 1           1.38846     1.04431               0.528832       0.687203                  44.2238
# 2           0.930918    0.85151               0.694174       0.755538                  95.4104
# 3           0.75367     0.82561               0.772216       0.741495                  146.755
# 4           0.697702    0.683632              0.778273       0.778481                  197.767
# [I 2019-11-01 22:25:35,684] Finished trial#1 resulted in value: 0.7790743670886076. Current best value is 0.779074367088608 with parameters: {'activation': 'tanh', 'layers': 25}.
# Layers: 94 Nodes: 3 Activation: sigmoid
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time

# %%
print('Minimum mean squared error: ' + str(study.best_value))
print('Best parameter: ' + str(study.best_params))

study.trials_dataframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b25cea2b1a94> in <module>()
# ----> 1 print('Minimum mean squared error: ' + str(study.best_value))
#       2 print('Best parameter: ' + str(study.best_params))
#       3
#       4 study.trials_dataframe()
#
# NameError: name 'study' is not defined
